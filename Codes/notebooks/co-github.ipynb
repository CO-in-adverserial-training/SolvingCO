# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("CO")

# %%
import os
os.chdir('/kaggle/working')
# !git clone https://{MazMazTey}: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@github.com/CO-in-adverserial-training/SolvingCO.git
# !git clone https://{farzanrahmani}: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@github.com/CO-in-adverserial-training/SolvingCO.git
# Out:
# Cloning into 'SolvingCO'...
# remote: Enumerating objects: 877, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 877 (delta 60), reused 32 (delta 17), pack-reused 782 (from 1)
# Receiving objects: 100% (877/877), 6.01 MiB | 35.59 MiB/s, done.
# Resolving deltas: 100% (596/596), done.

# %%
os.chdir('/kaggle/working/SolvingCO')
# !git pull
# Out:
# Already up to date.

# %%
import sys
sys.path.append('/kaggle/working/SolvingCO/Codes')

# %%
# !pip install torchhk -q
# !pip install medmnist -q
# !pip install timm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.5 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.2 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# os.chdir('/kaggle/working')
# !rm -r /kaggle/working/SolvingCO

# %%
# !python /kaggle/working/SolvingCO/Codes/main.py --root_path results --attack NFGSM --epochs 1

# %%
# !python /kaggle/working/SolvingCO/Codes/run_all.py
