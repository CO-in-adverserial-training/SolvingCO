# %%
import os
import subprocess

# %%
# !pip install timm -q

# %%
output = subprocess.check_output("pwd", shell=True, text=True)
print(output)  # This will print the current working directory
# Out:
# /home/frahmani/Github Code/SolvingCO/Codes

# %%
EPOCHS = 1

# %%
datasets = ["CIFAR10", "CIFAR100", "CINIC10", "SVHN", "TinyImageNet", "PathMNIST"]
models = ["PreActResNet18", "ResNet18", "WideResNet28", "SENet18", "VitSmall", "VitBase"]
attacks = ["FGSM", "FGSM-RS", "NFGSM", "ZeroGrad", "TRADES", "PGD"]
root_path = "results"

# %%
# output = subprocess.check_output(f"mkdir {root_path}", shell=True, text=True)
# output = os.popen(f"mkdir {root_path}").read()
print(output)

# output = subprocess.check_output(f'cd "catastrophic overfitting in adversarial robustness\SolvingCO\Codes"', shell=True, text=True)
# print(output)
# Out:
# /home/frahmani/Github Code/SolvingCO/Codes

# %%
for dataset in datasets:
    for model in models:
        for attack in attacks:
            print(f"Evaluating '{dataset}' dataset, '{model}' model, '{attack}' attack.")

            # output = os.popen(f"python main.py --root_path {root_path} --dataset {dataset} --model {model} --attack {attack} --epochs {EPOCHS}").read()
            output = subprocess.check_output(f"python main.py --root_path {root_path} --dataset {dataset} --model {model} --attack {attack} --epochs {EPOCHS}", shell=True, text=True)
            print(output)
            
            print("=" * 50)
# Out:
# Evaluating 'CIFAR10' dataset, 'PreActResNet18' model, 'FGSM' attack.
# Seed set to 42 for random, numpy, and torch (CPU & CUDA).
# Running on NVIDIA GeForce RTX 4090
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1 - Loss 2.1180, Accuracy: 20.40%, Time 20.6874
# Finished Training
# Total Training Time:  20.68736219406128
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0 - FGSM Accuracy: 0.36%, Benign Accuracy: 9.44%, FGSM Accuracy: 0.36%, PGD Accuracy: 0.53%, , Time 18.5602
# Epoch 1 - FGSM Accuracy: 28.43%, Benign Accuracy: 41.52%, FGSM Accuracy: 28.43%, PGD Accuracy: 30.01%, , Time 19.1615
# Finished Evaluating
# Total Evaluation Time:  37.72174072265625
# Figure(1500x500)
#
# ==================================================
# Evaluating 'CIFAR10' dataset, 'PreActResNet18' model, 'FGSM-RS' attack.
# Seed set to 42 for random, numpy, and torch (CPU & CUDA).
# Running on NVIDIA GeForce RTX 4090
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1 - Loss 2.0733, Accuracy: 22.10%, Time 20.2543
# Finished Training
# Total Training Time:  20.254340648651123
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0 - FGSM-RS Accuracy: 0.63%, Benign Accuracy: 9.44%, FGSM Accuracy: 0.36%, PGD Accuracy: 0.56%, , Time 18.0904
# Epoch 1 - FGSM-RS Accuracy: 29.64%, Benign Accuracy: 42.98%, FGSM Accuracy: 27.56%, PGD Accuracy: 29.44%, , Time 19.3354
# Finished Evaluating
# Total Evaluation Time:  37.4257869720459
# Figure(1500x500)
#
# ==================================================
# Evaluating 'CIFAR10' dataset, 'PreActResNet18' model, 'NFGSM' attack.
# Seed set to 42 for random, numpy, and torch (CPU & CUDA).
# Running on NVIDIA GeForce RTX 4090
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1 - Loss 2.1148, Accuracy: 20.61%, Time 19.9344
# Finished Training
# Total Training Time:  19.934394598007202
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0 - NFGSM Accuracy: 0.41%, Benign Accuracy: 9.44%, FGSM Accuracy: 0.36%, PGD Accuracy: 0.56%, , Time 18.9843
# Epoch 1 - NFGSM Accuracy: 28.59%, Benign Accuracy: 41.69%, FGSM Accuracy: 28.55%, PGD Accuracy: 30.28%, , Time 18.3189
# Finished Evaluating
# Total Evaluation Time:  37.303170680999756
# Figure(1500x500)
#
# ==================================================
# Evaluating 'CIFAR10' dataset, 'PreActResNet18' model, 'ZeroGrad' attack.
# Seed set to 42 for random, numpy, and torch (CPU & CUDA).
# Running on NVIDIA GeForce RTX 4090
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1 - Loss 1.9560, Accuracy: 26.92%, Time 21.2873
# Finished Training
# Total Training Time:  21.287288904190063
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0 - ZeroGrad Accuracy: 2.57%, Benign Accuracy: 9.44%, FGSM Accuracy: 0.36%, PGD Accuracy: 0.56%, , Time 19.0176
# Epoch 1 - ZeroGrad Accuracy: 40.77%, Benign Accuracy: 47.88%, FGSM Accuracy: 24.96%, PGD Accuracy: 27.15%, , Time 19.7963
# Finished Evaluating
# Total Evaluation Time:  38.81393027305603
# Figure(1500x500)
#
# ==================================================
# Evaluating 'CIFAR10' dataset, 'PreActResNet18' model, 'TRADES' attack.
# Traceback (most recent call last):
#   File "/home/frahmani/Github Code/SolvingCO/Codes/main.py", line 82, in <module>
#     main()
#   File "/home/frahmani/Github Code/SolvingCO/Codes/main.py", line 77, in main
#     evaluate(args, device)
#   File "/home/frahmani/Github Code/SolvingCO/Codes/evaluation/evaluation.py", line 57, in evaluate
#     delta, reg, _ = attack(model, images, labels, upper_limit, lower_limit, **attack_params)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: trades() missing 2 required positional arguments: 'mu' and 'std'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[27], line 7
#       4 print(f"Evaluating '{dataset}' dataset, '{model}' model, '{attack}' attack.")
#       6 # output = os.popen(f"python main.py --root_path {root_path} --dataset {dataset} --model {model} --attack {attack} --epochs {EPOCHS}").read()
# ----> 7 output = subprocess.check_output(f"python main.py --root_path {root_path} --dataset {dataset} --model {model} --attack {attack} --epochs {EPOCHS}", shell=True, text=True)
#       8 print(output)
#      10 print("=" * 50)
#
# File ~/miniconda3/envs/cenv/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~/miniconda3/envs/cenv/lib/python3.11/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command 'python main.py --root_path results --dataset CIFAR10 --model PreActResNet18 --attack TRADES --epochs 1' returned non-zero exit status 1.
